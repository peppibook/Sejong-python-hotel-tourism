# %%
import pandas as pd
reviews = pd.read_csv("../assets/winemag-data-130k-v2.csv", index_col=0)
pd.set_option("display.max_rows", 5)

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('points').price.mean()
# Out:
# points
# 80      16.372152
# 81      17.182353
#           ...
# 99     284.214286
# 100    485.947368
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmin()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  Ashy, green and funky smelling, then sweet, ch...
#           Other             Yellowish in color, a true indicator that this...
# ...                                                                       ...
# Uruguay   San Jose          Forceful, edgy aromas of cherry and drugstore ...
#           Uruguay           Aromas of sawmill and burnt wood are dominant....
#
#                               designation  points  price          province  \
# country   province
# Argentina Mendoza Province            NaN      80   17.0  Mendoza Province
#           Other                       NaN      80   13.0             Other
# ...                                   ...     ...    ...               ...
# Uruguay   San Jose          Parcela Vieja      82   20.0          San Jose
#           Uruguay                Traversa      81   12.0           Uruguay
#
#                            region_1 region_2        taster_name  \
# country   province
# Argentina Mendoza Province  Mendoza      NaN  Michael Schachner
#           Other               Salta      NaN  Michael Schachner
# ...                             ...      ...                ...
# Uruguay   San Jose              NaN      NaN  Michael Schachner
#           Uruguay               NaN      NaN  Michael Schachner
#
#                            taster_twitter_handle  \
# country   province
# Argentina Mendoza Province           @wineschach
#           Other                      @wineschach
# ...                                          ...
# Uruguay   San Jose                   @wineschach
#           Uruguay                    @wineschach
#
#                                                                         title  \
# country   province
# Argentina Mendoza Province     Bodega Carmine Granata 2009 Sémillon (Mendoza)
#           Other                             Villa Viña 2006 Torrontés (Salta)
# ...                                                                       ...
# Uruguay   San Jose          Castillo Viejo 2007 Parcela Vieja Cabernet Fra...
#           Uruguay           Familia Traversa 2014 Traversa Chardonnay (Uru...
#
#                                    variety                  winery
# country   province
# Argentina Mendoza Province        Sémillon  Bodega Carmine Granata
#           Other                  Torrontés              Villa Viña
# ...                                    ...                     ...
# Uruguay   San Jose          Cabernet Franc          Castillo Viejo
#           Uruguay               Chardonnay        Familia Traversa
#
# [425 rows x 13 columns]

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#               len   min    max
# country
# Argentina  3800.0   4.0  230.0
# Armenia       2.0  14.0   15.0
# ...           ...   ...    ...
# Ukraine      14.0   6.0   13.0
# Uruguay     109.0  10.0  130.0
#
# [43 rows x 3 columns]

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#      index country    province    len
# 392    392      US  California  36247
# 415    415      US  Washington   8639
# ..     ...     ...         ...    ...
# 63      63   Chile     Coelemu      1
# 149    149  Greece      Beotia      1
#
# [425 rows x 4 columns]

# %%
countries_reviewed.sort_index()
# Out:
#      index    country          province   len
# 0        0  Argentina  Mendoza Province  3264
# 1        1  Argentina             Other   536
# ..     ...        ...               ...   ...
# 423    423    Uruguay          San Jose     3
# 424    424    Uruguay           Uruguay    24
#
# [425 rows x 4 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#      index    country          province   len
# 1        1  Argentina             Other   536
# 0        0  Argentina  Mendoza Province  3264
# ..     ...        ...               ...   ...
# 424    424    Uruguay           Uruguay    24
# 419    419    Uruguay         Canelones    43
#
# [425 rows x 4 columns]

# %%
reviews.groupby('price')['points'].max() #.sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]
